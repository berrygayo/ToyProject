# %%
import pandas as pd

# %%
data=pd.read_excel('C:/Users/LENOVO/Documents/엔사이크 사업관련/팀별과제/GDP_domestic_v0.2_gy.xls')

# %%
data
# Out:
#    Unnamed: 0 국내총생산(명목GDP)  경제성장률(실질GDP성장률)
# 0     2010_01      307,738              7.3
# 1     2010_02      329,481              7.9
# 2     2010_03      334,834              5.8
# 3     2010_04      350,559              6.3
# 4     2011_01      328,096              5.4
# 5     2011_02      343,679              3.8
# 6     2011_03      349,987              3.1
# 7     2011_04      367,175              2.6
# 8     2012_01      344,575              2.4
# 9     2012_02      358,276              2.4
# 10    2012_03      361,834              2.3
# 11    2012_04      375,427              2.5
# 12    2013_01      355,385              2.3
# 13    2013_02      373,097              2.9
# 14    2013_03      379,887              3.5
# 15    2013_04      392,451              3.9
# 16    2014_01      373,560              3.8
# 17    2014_02      388,567              3.4
# 18    2014_03      393,425              3.1
# 19    2014_04      407,377              2.6
# ...

# %%
del data['국내총생산(명목GDP)']

# %%
data
# Out:
#    Unnamed: 0  경제성장률(실질GDP성장률)
# 0     2010_01              7.3
# 1     2010_02              7.9
# 2     2010_03              5.8
# 3     2010_04              6.3
# 4     2011_01              5.4
# 5     2011_02              3.8
# 6     2011_03              3.1
# 7     2011_04              2.6
# 8     2012_01              2.4
# 9     2012_02              2.4
# 10    2012_03              2.3
# 11    2012_04              2.5
# 12    2013_01              2.3
# 13    2013_02              2.9
# 14    2013_03              3.5
# 15    2013_04              3.9
# 16    2014_01              3.8
# 17    2014_02              3.4
# 18    2014_03              3.1
# 19    2014_04              2.6
# 20    2015_01              2.5
# 21    2015_02              2.0
# 22    2015_03              3.3
# 23    2015_04              3.4
# 24    2016_01              2.8
# 25    2016_02              3.6
# 26    2016_03              2.8
# 27    2016_04              2.7
# 28    2017_01              3.1
# ...

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
fig = plt.figure()
fig.suptitle('GDP plots')
# Out:
# Text(0.5, 0.98, 'GDP plots')

# %%
data['경제성장률(실질GDP성장률)'].plot.line()

# %%
import pandas as pd

# 문서별, 토픽별 키워드 빈도수 로드

D0_pre=pd.read_excel('error_Document_D0.xlsx')

# %%
# 일자별, 토픽별 키워드 빈도수의 평균 로드

D0_avg=pd.read_excel('error_Do_mean_day.xlsx')

# %%
# 확인

D0_pre
# Out:
#        Unnamed: 0                created_date  \
# 0               0  2015-01-07T21:19:00.000000
# 1               1  2015-01-07T20:41:00.000000
# 2               2  2015-01-07T19:55:00.000000
# 3               3  2015-01-07T19:04:00.000000
# 4               4  2015-01-07T19:02:00.000000
# ...           ...                         ...
# 86377       86377  2016-11-08T15:03:00.000000
# 86378       86378  2016-11-08T14:57:00.000000
# 86379       86379  2016-11-08T14:49:00.000000
# 86380       86380  2016-11-08T14:42:00.000000
# 86381       86381  2016-11-08T14:36:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# ...

# %%
len(D0_pre['c_pos_filter2'][0])
# Out:
# 439

# %%
# 사용안하는 컬럼 삭제

del D0_pre['Unnamed: 0']

# %%
# 확인

D0_pre
# Out:
#                      created_date  \
# 0      2015-01-07T21:19:00.000000
# 1      2015-01-07T20:41:00.000000
# 2      2015-01-07T19:55:00.000000
# 3      2015-01-07T19:04:00.000000
# 4      2015-01-07T19:02:00.000000
# ...                           ...
# 86377  2016-11-08T15:03:00.000000
# 86378  2016-11-08T14:57:00.000000
# 86379  2016-11-08T14:49:00.000000
# 86380  2016-11-08T14:42:00.000000
# 86381  2016-11-08T14:36:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# 4      ['특허권', '자체', '기능', '에이', '공시', '취득', '관련', '방...       0       1
# ...                                                  ...     ...     ...
# ...

# %%
D0_pre['topic0'][0]
# Out:
# 0

# %%
# 확인

D0_avg
# Out:
#      Unnamed: 0  Unnamed: 0.1  count  topic0_mean  topic1_mean  topic2_mean  \
# 0             0             0    108     2.250000     1.527778     2.555556
# 1             1             1    120     1.083333     1.400000     1.866667
# 2             2             2     12     2.166667     2.083333     2.500000
# 3             3             3     61     2.426230     3.672131     2.836066
# 4             4             4    162     1.345679     1.327160     1.308642
# ..          ...           ...    ...          ...          ...          ...
# 718         718           718    128     2.609375     1.570312     0.890625
# 719         719           719    152     0.980263     1.473684     1.105263
# 720         720           720    191     1.418848     0.895288     1.675393
# 721         721           721     70     3.057143     2.271429     3.028571
# 722         722           722     24     1.708333     3.208333     2.166667
#
# ...

# %%
# 이용안하는 컬럼 삭제

del D0_avg['count']

# %%
D0_avg
# Out:
#      Unnamed: 0  Unnamed: 0.1  topic0_mean  topic1_mean  topic2_mean  \
# 0             0             0     2.250000     1.527778     2.555556
# 1             1             1     1.083333     1.400000     1.866667
# 2             2             2     2.166667     2.083333     2.500000
# 3             3             3     2.426230     3.672131     2.836066
# 4             4             4     1.345679     1.327160     1.308642
# ..          ...           ...          ...          ...          ...
# 718         718           718     2.609375     1.570312     0.890625
# 719         719           719     0.980263     1.473684     1.105263
# 720         720           720     1.418848     0.895288     1.675393
# 721         721           721     3.057143     2.271429     3.028571
# 722         722           722     1.708333     3.208333     2.166667
#
#      topic3_mean  topic4_mean  topic5_mean  topic6_mean  topic7_mean  ...  \
# ...

# %% [markdown]
# # 문서별, 토픽별 키워드 빈도수 데이터와 일자별, 토픽별 키워드 빈도수의 평균 데이터 mrege

# %%
Dk0_1=pd.merge(D0_pre,D0_avg)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-11-63767840d942> in <module>
# ----> 1 Dk0_1=pd.merge(D0_pre,D0_avg)
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      80         copy=copy,
#      81         indicator=indicator,
# ---> 82         validate=validate,
#      83     )
#      84     return op.get_result()
#
# ~\Anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     618             warnings.warn(msg, UserWarning)
#     619
# --> 620         self._validate_specification()
#     621
#     622         # note this function has side effects
#
# ...

# %%
Dk0_1
# Out:
#                      created_date  \
# 0      2015-01-07T21:19:00.000000
# 1      2015-01-07T20:41:00.000000
# 2      2015-01-07T19:55:00.000000
# 3      2015-01-07T19:04:00.000000
# 4      2015-01-07T19:02:00.000000
# ...                           ...
# 86377  2016-10-05T09:00:00.000000
# 86378  2016-10-05T08:34:00.000000
# 86379  2016-10-05T07:17:00.000000
# 86380  2016-10-05T06:55:00.000000
# 86381  2016-10-05T06:02:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# 4      ['특허권', '자체', '기능', '에이', '공시', '취득', '관련', '방...       0       1
# ...                                                  ...     ...     ...
# ...

# %%
len(Dk0_1['c_pos_filter2'][0])
# Out:
# 439

# %% [markdown]
# # 평균 이상인 데이터만 추출

# %%
# 평균이하를 0으로 처리

for i in range(20):
    for j in range(len(Dk0_1)):
        if Dk0_1['topic{}'.format(i)][j] < Dk0_1['topic{}_mean'.format(i)][j]: # 토픽i의 j번째가 평균 토픽i의 j번째보다 작으면 
            Dk0_1['topic{}'.format(i)][j]=0           # 토픽 i의 j번째를 0으로 변경한다
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Dk0_1
# Out:
#                      created_date  \
# 0      2015-01-07T21:19:00.000000
# 1      2015-01-07T20:41:00.000000
# 2      2015-01-07T19:55:00.000000
# 3      2015-01-07T19:04:00.000000
# 4      2015-01-07T19:02:00.000000
# ...                           ...
# 86377  2016-10-05T09:00:00.000000
# 86378  2016-10-05T08:34:00.000000
# 86379  2016-10-05T07:17:00.000000
# 86380  2016-10-05T06:55:00.000000
# 86381  2016-10-05T06:02:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# 4      ['특허권', '자체', '기능', '에이', '공시', '취득', '관련', '방...       0       0
# ...                                                  ...     ...     ...
# ...

# %%
del Dk0_1['topic0_mean']
del Dk0_1['topic1_mean']
del Dk0_1['topic2_mean']
del Dk0_1['topic3_mean']
del Dk0_1['topic4_mean']
del Dk0_1['topic5_mean']
del Dk0_1['topic6_mean']
del Dk0_1['topic7_mean']
del Dk0_1['topic8_mean']
del Dk0_1['topic9_mean']
del Dk0_1['topic10_mean']
del Dk0_1['topic11_mean']
del Dk0_1['topic12_mean']
del Dk0_1['topic13_mean']
del Dk0_1['topic14_mean']
del Dk0_1['topic15_mean']
del Dk0_1['topic16_mean']
del Dk0_1['topic17_mean']
del Dk0_1['topic18_mean']
del Dk0_1['topic19_mean']

# %%
Dk0_1
# Out:
#                      created_date  \
# 0      2015-01-07T21:19:00.000000
# 1      2015-01-07T20:41:00.000000
# 2      2015-01-07T19:55:00.000000
# 3      2015-01-07T19:04:00.000000
# 4      2015-01-07T19:02:00.000000
# ...                           ...
# 86377  2016-10-05T09:00:00.000000
# 86378  2016-10-05T08:34:00.000000
# 86379  2016-10-05T07:17:00.000000
# 86380  2016-10-05T06:55:00.000000
# 86381  2016-10-05T06:02:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# 4      ['특허권', '자체', '기능', '에이', '공시', '취득', '관련', '방...       0       0
# ...                                                  ...     ...     ...
# ...

# %%
Dk0_1['c_pos_filter2'][0]
# Out:
# "['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회생', '증권', '열사', '지방법원', '유상증자', '플레이', '위해', '월드', '앤리', '보통주', '미래에셋', '체제', '반도체', '터보', '건설', '허브', '보호', '흡수', '관련', '네트워크', '실권', '규모', '국적', '개시', '확보', '처분', '시스템', '실사', '기업', '결정', '대표', '특허', '시설', '제철', '예비', '퇴임', '중앙', '변경', '멀티캐스트', '장치', '덕통', '볼팅', '홀딩스', '주주', '합병', '배정', '협상', '절차', '에이', '와이드', '자동', '자회사', '보유', '방식', '사외이사', '중도', '취득', '엔터테인먼트', '전량', '테크', '마련', '신청']"

# %%
# pos_t 리스트안의 문자형 분리

pos_f=[]
for j in Dk0_1['c_pos_filter2']:
    pos_f.append(j.split(','))
        
pos_f[0]
# Out:
# ["['만료'",
#  " '스틸'",
#  " '자금'",
#  " '유동성'",
#  " '공동'",
#  " '최대'",
#  " '매각'",
#  " '회생'",
#  " '증권'",
#  " '열사'",
#  " '지방법원'",
#  " '유상증자'",
#  " '플레이'",
#  " '위해'",
#  " '월드'",
#  " '앤리'",
#  " '보통주'",
#  " '미래에셋'",
#  " '체제'",
#  " '반도체'",
#  " '터보'",
#  " '건설'",
#  " '허브'",
#  " '보호'",
#  " '흡수'",
#  " '관련'",
#  " '네트워크'",
#  " '실권'",
#  " '규모'",
#  " '국적'",
#  " '개시'",
#  " '확보'",
#  " '처분'",
#  " '시스템'",
#  " '실사'",
#  " '기업'",
#  " '결정'",
#  " '대표'",
#  " '특허'",
#  " '시설'",
#  " '제철'",
#  " '예비'",
#  " '퇴임'",
#  " '중앙'",
#  " '변경'",
#  " '멀티캐스트'",
#  " '장치'",
#  " '덕통'",
#  " '볼팅'",
#  " '홀딩스'",
#  " '주주'",
#  " '합병'",
#  " '배정'",
#  " '협상'",
#  " '절차'",
#  " '에이'",
#  " '와이드'",
#  " '자동'",
#  " '자회사'",
#  " '보유'",
#  " '방식'",
#  " '사외이사'",
#  " '중도'",
#  " '취득'",
#  " '엔터테인먼트'",
#  " '전량'",
#  " '테크'",
#  " '마련'",
#  " '신청']"]

# %%
# 특수문자 제거

pos_f_st=[]
for i in range(len(Dk0_1)):
    pos_f_st2=[]
    for j in pos_f[i]:
        pos_f_st2.append(j.lstrip('[').rstrip('"]').strip(" ' "))
    pos_f_st.append(pos_f_st2)

pos_f_st[0][1]
# Out:
# '스틸'

# %%
len(pos_f_st[0])
# Out:
# 69

# %%
Dk0_1['pos_t0']=pos_f_st
Dk0_1['pos_t1']=pos_f_st
Dk0_1['pos_t2']=pos_f_st
Dk0_1['pos_t3']=pos_f_st
Dk0_1['pos_t4']=pos_f_st
Dk0_1['pos_t5']=pos_f_st
Dk0_1['pos_t6']=pos_f_st
Dk0_1['pos_t7']=pos_f_st
Dk0_1['pos_t8']=pos_f_st
Dk0_1['pos_t9']=pos_f_st
Dk0_1['pos_t10']=pos_f_st
Dk0_1['pos_t11']=pos_f_st
Dk0_1['pos_t12']=pos_f_st
Dk0_1['pos_t13']=pos_f_st
Dk0_1['pos_t14']=pos_f_st
Dk0_1['pos_t15']=pos_f_st
Dk0_1['pos_t16']=pos_f_st
Dk0_1['pos_t17']=pos_f_st
Dk0_1['pos_t18']=pos_f_st
Dk0_1['pos_t19']=pos_f_st

# %%
Dk0_1
# Out:
#                      created_date  \
# 0      2015-01-07T21:19:00.000000
# 1      2015-01-07T20:41:00.000000
# 2      2015-01-07T19:55:00.000000
# 3      2015-01-07T19:04:00.000000
# 4      2015-01-07T19:02:00.000000
# ...                           ...
# 86377  2016-10-05T09:00:00.000000
# 86378  2016-10-05T08:34:00.000000
# 86379  2016-10-05T07:17:00.000000
# 86380  2016-10-05T06:55:00.000000
# 86381  2016-10-05T06:02:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# 4      ['특허권', '자체', '기능', '에이', '공시', '취득', '관련', '방...       0       0
# ...                                                  ...     ...     ...
# ...

# %%
# 토픽이 0이 아닌 일자의 pos를 빈리스트로 변경
em_li=[]
for i in range(20):
    for j in range(len(Dk0_1)):
        if Dk0_1['topic{}'.format(i)][j] == 0:
            Dk0_1['pos_t{}'.format(i)][j]=em_li
        #else:
        #    print(Dk0_1['pos_t{}'.format(i)][j])
# Out:
# C:\Users\LENOVO\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Dk0_1
# Out:
#                      created_date  \
# 0      2015-01-07T21:19:00.000000
# 1      2015-01-07T20:41:00.000000
# 2      2015-01-07T19:55:00.000000
# 3      2015-01-07T19:04:00.000000
# 4      2015-01-07T19:02:00.000000
# ...                           ...
# 86377  2016-10-05T09:00:00.000000
# 86378  2016-10-05T08:34:00.000000
# 86379  2016-10-05T07:17:00.000000
# 86380  2016-10-05T06:55:00.000000
# 86381  2016-10-05T06:02:00.000000
#
#                                            c_pos_filter2  topic0  topic1  \
# 0      ['만료', '스틸', '자금', '유동성', '공동', '최대', '매각', '회...       0       2
# 1      ['수단', '주인공', '현실', '환경', '반응', '최대', '핸들', '통...       0       3
# 2      ['미국', '초고', '샤프', '회장', '참석', '적용', '차지', '고민...       0       2
# 3      ['판독', '사유', '무상증자', '소송', '종목', '모바일', '지방법원'...       4       4
# 4      ['특허권', '자체', '기능', '에이', '공시', '취득', '관련', '방...       0       0
# ...                                                  ...     ...     ...
# ...

# %%
# 부분 파일 엑셀로 저장

#Dk0_1.to_excel('D:\\toy\\data\\Dk0_1.xlsx',index=False)

# %% [markdown]
# # 일별 키워드 중복제거

# %%
Dk0_2=Dk0_1

# %%
Dk0_2['ymd']
# Out:
# 0        2015-01-07
# 1        2015-01-07
# 2        2015-01-07
# 3        2015-01-07
# 4        2015-01-07
#             ...
# 86377    2016-10-05
# 86378    2016-10-05
# 86379    2016-10-05
# 86380    2016-10-05
# 86381    2016-10-05
# Name: ymd, Length: 86382, dtype: object

# %%
del Dk0_2['created_date']
del Dk0_2['c_pos_filter2']
del Dk0_2['topic0']
del Dk0_2['topic1']
del Dk0_2['topic2']
del Dk0_2['topic3']
del Dk0_2['topic4']
del Dk0_2['topic5']
del Dk0_2['topic6']
del Dk0_2['topic7']
del Dk0_2['topic8']
del Dk0_2['topic9']
del Dk0_2['topic10']
del Dk0_2['topic11']
del Dk0_2['topic12']
del Dk0_2['topic13']
del Dk0_2['topic14']
del Dk0_2['topic15']
del Dk0_2['topic16']
del Dk0_2['topic17']
del Dk0_2['topic18']
del Dk0_2['topic19']

# %%
Dk0_2
# Out:
#               ymd                                             pos_t0  \
# 0      2015-01-07                                                 []
# 1      2015-01-07                                                 []
# 2      2015-01-07                                                 []
# 3      2015-01-07  [판독, 사유, 무상증자, 소송, 종목, 모바일, 지방법원, 지난, 대표이사, 설계...
# 4      2015-01-07                                                 []
# ...           ...                                                ...
# 86377  2016-10-05  [종가, 추이, 상태, 기사, 종목, 모바일, 대감, 리콜, 지난, 동향, 초반, ...
# 86378  2016-10-05  [코스피, 마이너스, 소송, 환경, 견조, 완화, 종목, 가능성, 대감, 미국, 치...
# 86379  2016-10-05                                                 []
# 86380  2016-10-05                                                 []
# 86381  2016-10-05  [특수, 코스피, 가공, 지주, 열사, 자산, 유형, 지난, 문제, 적용, 소유, ...
#
#                                                   pos_t1  \
# 0      [만료, 스틸, 자금, 유동성, 공동, 최대, 매각, 회생, 증권, 열사, 지방법원...
# ...

# %%
Dk_3=Dk0_2.groupby('ymd').sum()

# %%
Dk_3
# Out:
#                                                        pos_t0  \
# ymd
# 2015-01-01  [효자, 자원부, 산업, 중국, 미국, 반면, 무역, 국제, 석유화학, 반도체, 견...
# 2015-01-02  [코스피, 종목, 반면, 지배구조, 중소형주, 보이, 생명, 기대, 브로드밴드, 회...
# 2015-01-03  [코스피, 집권, 급진좌파, 중식, 미국, 가능성, 지난, 어닝, 긴축, 보합, 부...
# 2015-01-04  [부진, 코스피, 효과, 심리, 시장, 공개시장, 태동, 종목, 가능성, 대감, 미...
# 2015-01-05  [도입, 시장, 포인트, 환경, 신규, 사용, 모바일, 재량, 증권, 투자, 기여,...
# ...                                                       ...
# 2016-12-27  [특수, 부진, 팩트, 자초, 리더, 담뱃세, 뒷북, 공략, 가속, 고교생, 라운지...
# 2016-12-28  [블룸버그, 이득, 상태, 활용, 가능성, 미국, 침입, 지난, 현지, 체인, 적발...
# 2016-12-29  [개장, 가능성, 사용, 미국, 지난, 상품거래소, 세력, 문제, 기준금리, 규모,...
# 2016-12-30  [유입, 지주, 자금, 완화, 미국, 장기, 매물, 철강, 스마트폰, 은행, 방직,...
# 2016-12-31  [효과, 조업, 발굴, 경기도, 최대, 산업, 수급, 중국, 대비, 기조, 지원, ...
#
#                                                        pos_t1  \
# ymd
# 2015-01-01  [시장, 트렌드, 본격, 경쟁력, 거세, 전자제품, 명품, 최대, 산업, 중국, 모...
# 2015-01-02  [역할, 집권, 관건, 현실, 명품, 새삼, 명암, 리더, 미국, 활용, 가능성, ...
# ...

# %%
len(Dk_3['pos_t0'][0])
# Out:
# 6686

# %%
len(set(Dk_3['pos_t0'][0]))
# Out:
# 1532

# %%
len(Dk_3['pos_t1'][0])
# Out:
# 8867

# %%
len(set(Dk_3['pos_t1'][0]))
# Out:
# 2360

# %%
# 엑셀 저장

Dk_3.to_excel('D:\\toy\\data\\Dk_3.xlsx',index=False)

# %% [markdown]
# # 평균으로 걸러낸 문서의 키워드 빈도수 일자별로 합하기

# %%
Dk0=pd.DataFrame(Dk0_1).groupby('ymd').sum()

# %%
Dk0
